# %% [markdown]
# s# Class 102 at Gervi-Hera-Vitr
#
# We are learning about machine learning from Google!
#
# - Here is the [Machine Learning Foundations YouTube Class](https://youtube.com/playlist?list=PLOU2XLYxmsII9mzQ-Xxug4l2o04JBrkLV&si=13sb6VTquza6cmUA
# ) that we follow.
#
# - And here is the [Captain Lugaru's Assignment Miro Board](https://miro.com/app/board/uXjVL-vk0o4=/ "Episodes Explained")

# %% [markdown]
#  Episode 1: Basics of ML.
#  Ok, so what is ML?:
#  Machine learning is a branch of Ai that enables computer systems to learn and improve from experience without being explicitly programmed. It focuses on creating algorithms and models that can analyze data, identify patterns, and make decisions or predictions based on that data. Ml is not Like traditional programming:
#  ![](./rules-data-logic-answers.png)

# %% [markdown]
# Ok, so rules + data goes into traditional programming give you answers, but with Machine learning you put in data and answers to get out perfect rules, so that later you can have the model predict the other answers much better and faster than traditional programming using these new rules, ok? well now we are going to look at how a neural network works down below:

# %% [markdown]
# ![](layers.png)

# %% [markdown]
# A group of Neurons that are side by side is called a layer, and you can have multiple layers that all communicate with each other and eventually coming up with a prediction or solution. but now that you understand the very basics of ML we will start Class 1 Coding aka the "hello world" of ML!:

# %%
import keras # imports
import numpy as np
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])]) # This line creates a machine learning model using Keras, structured as a sequence of layers. It has a single dense (fully connected) layer with 1 unit (neuron) and expects input data with one feature (dimension).

model.compile(optimizer='sgd', loss='mean_squared_error') # This line sets up the model to learn by using the Stochastic Gradient Descent (SGD) optimizer to update its weights. It uses mean squared error to measure how far predictions are from the actual values during training.

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float) # data used for x and y arrays
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=200)#model is fitted and trained on the x and y and is given a number of epochs

outcome = model.predict(np.array([4.0]))# model predicts what an x of 4 will mean for y
print(outcome.round()) # should predict the right answer: 7.
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - loss: 34.5740
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 27.5337
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 21.9879
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 17.6181
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 14.1735
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 11.4571
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 9.3137
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 7.6211
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 6.2835
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 5.2252
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 4.3869
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.7216
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.1926
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.7710
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.4340
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 2.1637
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.9459
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.7695
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.6258
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.5080
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.4106
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.3294
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.2609
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.2027
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.1525
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.1088
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.0703
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.0359
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.0049
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.9766
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.9505
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.9262
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.9035
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.8820
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.8615
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.8420
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.8233
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.8053
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.7878
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.7710
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.7546
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.7386
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.7231
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.7080
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.6933
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.6789
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.6648
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.6510
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.6376
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.6244
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.6115
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.5989
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.5866
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.5745
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.5627
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.5511
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.5398
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.5287
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.5178
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.5072
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.4968
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.4866
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.4766
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.4668
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.4572
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.4478
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4386
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.4296
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.4208
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.4121
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.4037
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.3954
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.3872
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.3793
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.3715
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.3639
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.3564
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.3491
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.3419
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.3349
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.3280
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.3213
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.3147
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.3082
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.3019
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2957
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2896
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2836
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2778
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2721
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2665
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2610
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2557
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2504
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2453
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2403
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2353
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2305
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2257
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.2211
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2166
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2121
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2078
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2035
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1993
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1952
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1912
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1873
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1834
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1797
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1760
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1724
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1688
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1654
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1620
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1586
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1554
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1522
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1491
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1460
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1430
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1401
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1372
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1344
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1316
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1289
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1263
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1237
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1211
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1186
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1162
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1138
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1115
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1092
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1069
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1047
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1026
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1005
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0984
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0964
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0944
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0925
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0906
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0887
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0869
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0851
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0834
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0817
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0800
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0783
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0767
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0751
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0736
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0721
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0706
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0692
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0677
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0663
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0650
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0636
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0623
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0611
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0598
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0586
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0574
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0562
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0550
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0539
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0528
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0517
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0507
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0496
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0486
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0476
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0466
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0457
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0447
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0438
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0429
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0420
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0412
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0403
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0395
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0387
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0379
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0371
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0363
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0356
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0349
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0341
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0334
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0328
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0321
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0314
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0308
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0302
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0295
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0289
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0283
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0277
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# [[7.]]

# %% [markdown]
# Now,Here is the Exercise for the episode and if you are stuck with it the answer is down below:
# https://colab.research.google.com/github/lmoroney/dlaicourse/blob/master/Exercises/Exercise%201%20-%20House%20Prices/Exercise_1_House_Prices_Question.ipynb

# %%
import tensorflow as tf
import numpy as np
import keras

# Define the model: a simple Sequential model with one dense layer
model = keras.Sequential([
    keras.layers.Dense(units=1, input_shape=[1])  # One neuron, one input feature
])

# Compile the model: specify optimizer, loss function, and metrics
model.compile(optimizer='sgd',  # Stochastic Gradient Descent optimizer
              loss='mean_squared_error')  # Use mean squared error for regression tasks

# Input data (xs) and output data (ys) representing a simple linear relationship
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)  # Example inputs
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)  # Corresponding outputs

# Train the model
model.fit(xs, ys, epochs=500)  # Train for 500 epochs to minimize loss

# Use the model to predict a value
print(model.predict(np.array([7.0])))
  # Predict the output for input 7.0
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - loss: 26.4432
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 21.1012
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 16.8923
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 13.5749
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 10.9591
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 8.8954
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 7.2662
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 5.9789
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 4.9607
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 4.1544
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 3.5149
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 3.0066
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 2.6018
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 2.2785
# Epoch 15/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.0194
# Epoch 16/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.8108
# Epoch 17/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.6422
# Epoch 18/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.5051
# Epoch 19/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.3928
# Epoch 20/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.3002
# Epoch 21/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.2231
# Epoch 22/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.1584
# Epoch 23/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.1034
# Epoch 24/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.0562
# Epoch 25/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.0152
# Epoch 26/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.9792
# Epoch 27/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.9471
# Epoch 28/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.9183
# Epoch 29/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.8920
# Epoch 30/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.8679
# Epoch 31/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.8455
# Epoch 32/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.8245
# Epoch 33/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.8048
# Epoch 34/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.7860
# Epoch 35/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.7681
# Epoch 36/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.7509
# Epoch 37/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.7344
# Epoch 38/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.7185
# Epoch 39/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.7031
# Epoch 40/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.6881
# Epoch 41/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.6735
# Epoch 42/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.6594
# Epoch 43/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.6456
# Epoch 44/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.6321
# Epoch 45/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.6190
# Epoch 46/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.6061
# Epoch 47/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.5936
# Epoch 48/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.5813
# Epoch 49/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.5693
# Epoch 50/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.5576
# Epoch 51/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.5461
# Epoch 52/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.5348
# Epoch 53/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.5238
# Epoch 54/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.5131
# Epoch 55/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.5025
# Epoch 56/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.4922
# Epoch 57/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.4820
# Epoch 58/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.4721
# Epoch 59/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.4624
# Epoch 60/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.4529
# Epoch 61/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.4436
# Epoch 62/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.4345
# Epoch 63/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.4256
# Epoch 64/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.4168
# Epoch 65/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.4083
# Epoch 66/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.3999
# Epoch 67/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.3917
# Epoch 68/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.3836
# Epoch 69/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.3757
# Epoch 70/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.3680
# Epoch 71/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.3605
# Epoch 72/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.3531
# Epoch 73/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.3458
# Epoch 74/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.3387
# Epoch 75/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3318
# Epoch 76/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.3249
# Epoch 77/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.3183
# Epoch 78/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.3117
# Epoch 79/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.3053
# Epoch 80/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2991
# Epoch 81/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2929
# Epoch 82/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2869
# Epoch 83/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2810
# Epoch 84/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2752
# Epoch 85/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2696
# Epoch 86/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2640
# Epoch 87/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2586
# Epoch 88/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.2533
# Epoch 89/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2481
# Epoch 90/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.2430
# Epoch 91/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2380
# Epoch 92/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2331
# Epoch 93/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2283
# Epoch 94/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2236
# Epoch 95/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2190
# Epoch 96/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2145
# Epoch 97/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.2101
# Epoch 98/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2058
# Epoch 99/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2016
# Epoch 100/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1975
# Epoch 101/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1934
# Epoch 102/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1894
# Epoch 103/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1855
# Epoch 104/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1817
# Epoch 105/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1780
# Epoch 106/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1743
# Epoch 107/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1708
# Epoch 108/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1672
# Epoch 109/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1638
# Epoch 110/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1604
# Epoch 111/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1572
# Epoch 112/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.1539
# Epoch 113/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1508
# Epoch 114/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1477
# Epoch 115/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.1446
# Epoch 116/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1417
# Epoch 117/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1388
# Epoch 118/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.1359
# Epoch 119/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1331
# Epoch 120/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1304
# Epoch 121/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1277
# Epoch 122/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1251
# Epoch 123/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1225
# Epoch 124/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1200
# Epoch 125/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1175
# Epoch 126/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1151
# Epoch 127/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1127
# Epoch 128/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1104
# Epoch 129/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1082
# Epoch 130/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1059
# Epoch 131/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1038
# Epoch 132/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1016
# Epoch 133/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0995
# Epoch 134/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0975
# Epoch 135/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0955
# Epoch 136/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0935
# Epoch 137/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0916
# Epoch 138/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0897
# Epoch 139/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0879
# Epoch 140/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0861
# Epoch 141/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0843
# Epoch 142/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0826
# Epoch 143/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0809
# Epoch 144/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0792
# Epoch 145/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0776
# Epoch 146/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0760
# Epoch 147/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0744
# Epoch 148/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0729
# Epoch 149/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0714
# Epoch 150/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0700
# Epoch 151/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0685
# Epoch 152/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0671
# Epoch 153/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0657
# Epoch 154/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0644
# Epoch 155/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0631
# Epoch 156/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0618
# Epoch 157/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0605
# Epoch 158/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0592
# Epoch 159/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0580
# Epoch 160/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0568
# Epoch 161/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0557
# Epoch 162/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0545
# Epoch 163/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0534
# Epoch 164/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0523
# Epoch 165/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0512
# Epoch 166/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0502
# Epoch 167/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0492
# Epoch 168/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0481
# Epoch 169/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0472
# Epoch 170/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0462
# Epoch 171/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0452
# Epoch 172/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0443
# Epoch 173/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0434
# Epoch 174/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0425
# Epoch 175/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0416
# Epoch 176/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0408
# Epoch 177/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0399
# Epoch 178/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0391
# Epoch 179/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0383
# Epoch 180/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0375
# Epoch 181/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0368
# Epoch 182/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0360
# Epoch 183/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0353
# Epoch 184/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0345
# Epoch 185/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0338
# Epoch 186/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0331
# Epoch 187/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0325
# Epoch 188/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0318
# Epoch 189/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0311
# Epoch 190/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0305
# Epoch 191/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0299
# Epoch 192/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0293
# Epoch 193/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0287
# Epoch 194/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0281
# Epoch 195/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0275
# Epoch 196/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0269
# Epoch 197/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0264
# Epoch 198/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0258
# Epoch 199/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0253
# Epoch 200/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0248
# Epoch 201/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0243
# Epoch 202/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0238
# Epoch 203/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0233
# Epoch 204/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0228
# Epoch 205/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0223
# Epoch 206/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0219
# Epoch 207/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0214
# Epoch 208/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0210
# Epoch 209/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0206
# Epoch 210/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0201
# Epoch 211/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0197
# Epoch 212/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0193
# Epoch 213/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0189
# Epoch 214/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0185
# Epoch 215/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0182
# Epoch 216/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0178
# Epoch 217/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0174
# Epoch 218/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0171
# Epoch 219/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0167
# Epoch 220/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0164
# Epoch 221/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0160
# Epoch 222/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0157
# Epoch 223/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0154
# Epoch 224/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0151
# Epoch 225/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0147
# Epoch 226/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0144
# Epoch 227/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0141
# Epoch 228/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0139
# Epoch 229/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.0136
# Epoch 230/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0133
# Epoch 231/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0130
# Epoch 232/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0128
# Epoch 233/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0125
# Epoch 234/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0122
# Epoch 235/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0120
# Epoch 236/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0117
# Epoch 237/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0115
# Epoch 238/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0113
# Epoch 239/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0110
# Epoch 240/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0108
# Epoch 241/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0106
# Epoch 242/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0104
# Epoch 243/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0102
# Epoch 244/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0099
# Epoch 245/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0097
# Epoch 246/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0095
# Epoch 247/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0093
# Epoch 248/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0092
# Epoch 249/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0090
# Epoch 250/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0088
# Epoch 251/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0086
# Epoch 252/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0084
# Epoch 253/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0082
# Epoch 254/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0081
# Epoch 255/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0079
# Epoch 256/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0078
# Epoch 257/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0076
# Epoch 258/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0074
# Epoch 259/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0073
# Epoch 260/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0071
# Epoch 261/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0070
# Epoch 262/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0068
# Epoch 263/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0067
# Epoch 264/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0066
# Epoch 265/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0064
# Epoch 266/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0063
# Epoch 267/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0062
# Epoch 268/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0060
# Epoch 269/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0059
# Epoch 270/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0058
# Epoch 271/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0057
# Epoch 272/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0056
# Epoch 273/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0054
# Epoch 274/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0053
# Epoch 275/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0052
# Epoch 276/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0051
# Epoch 277/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0050
# Epoch 278/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0049
# Epoch 279/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0048
# Epoch 280/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0047
# Epoch 281/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0046
# Epoch 282/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0045
# Epoch 283/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0044
# Epoch 284/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0043
# Epoch 285/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0042
# Epoch 286/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0042
# Epoch 287/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0041
# Epoch 288/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0040
# Epoch 289/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0039
# Epoch 290/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0038
# Epoch 291/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0037
# Epoch 292/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0037
# Epoch 293/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0036
# Epoch 294/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0035
# Epoch 295/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0035
# Epoch 296/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0034
# Epoch 297/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0033
# Epoch 298/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0032
# Epoch 299/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0032
# Epoch 300/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0031
# Epoch 301/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0030
# Epoch 302/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0030
# Epoch 303/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0029
# Epoch 304/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0029
# Epoch 305/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0028
# Epoch 306/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0027
# Epoch 307/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0027
# Epoch 308/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0026
# Epoch 309/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0026
# Epoch 310/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0025
# Epoch 311/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0025
# Epoch 312/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0024
# Epoch 313/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0024
# Epoch 314/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0023
# Epoch 315/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0023
# Epoch 316/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0022
# Epoch 317/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0022
# Epoch 318/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0021
# Epoch 319/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0021
# Epoch 320/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0021
# Epoch 321/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0020
# Epoch 322/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0020
# Epoch 323/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0019
# Epoch 324/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0019
# Epoch 325/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0019
# Epoch 326/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0018
# Epoch 327/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0018
# Epoch 328/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0017
# Epoch 329/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0017
# Epoch 330/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0017
# Epoch 331/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0016
# Epoch 332/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0016
# Epoch 333/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0016
# Epoch 334/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0015
# Epoch 335/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0015
# Epoch 336/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0015
# Epoch 337/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0014
# Epoch 338/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0014
# Epoch 339/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0014
# Epoch 340/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0014
# Epoch 341/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0013
# Epoch 342/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0013
# Epoch 343/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0013
# Epoch 344/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0012
# Epoch 345/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0012
# Epoch 346/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0012
# Epoch 347/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0012
# Epoch 348/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0011
# Epoch 349/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0011
# Epoch 350/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0011
# Epoch 351/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0011
# Epoch 352/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0011
# Epoch 353/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0010
# Epoch 354/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0010
# Epoch 355/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 9.9315e-04
# Epoch 356/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 9.7275e-04
# Epoch 357/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 9.5277e-04
# Epoch 358/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 9.3320e-04
# Epoch 359/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 9.1403e-04
# Epoch 360/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 8.9526e-04
# Epoch 361/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 8.7687e-04
# Epoch 362/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 8.5886e-04
# Epoch 363/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 8.4122e-04
# Epoch 364/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 8.2394e-04
# Epoch 365/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 8.0702e-04
# Epoch 366/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 7.9044e-04
# Epoch 367/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 7.7420e-04
# Epoch 368/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 7.5830e-04
# Epoch 369/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 7.4272e-04
# Epoch 370/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 7.2747e-04
# Epoch 371/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 7.1253e-04
# Epoch 372/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 6.9789e-04
# Epoch 373/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 6.8356e-04
# Epoch 374/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 6.6952e-04
# Epoch 375/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 6.5576e-04
# Epoch 376/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 6.4229e-04
# Epoch 377/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 6.2910e-04
# Epoch 378/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 6.1617e-04
# Epoch 379/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 6.0352e-04
# Epoch 380/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 5.9112e-04
# Epoch 381/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 5.7898e-04
# Epoch 382/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 5.6709e-04
# Epoch 383/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 5.5544e-04
# Epoch 384/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 5.4403e-04
# Epoch 385/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 5.3285e-04
# Epoch 386/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 5.2191e-04
# Epoch 387/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 5.1119e-04
# Epoch 388/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 5.0069e-04
# Epoch 389/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 4.9041e-04
# Epoch 390/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 4.8033e-04
# Epoch 391/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 4.7047e-04
# Epoch 392/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 4.6080e-04
# Epoch 393/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 4.5134e-04
# Epoch 394/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 4.4207e-04
# Epoch 395/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 4.3299e-04
# Epoch 396/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 4.2409e-04
# Epoch 397/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 4.1538e-04
# Epoch 398/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 4.0685e-04
# Epoch 399/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 3.9849e-04
# Epoch 400/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 3.9031e-04
# Epoch 401/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.8229e-04
# Epoch 402/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 3.7444e-04
# Epoch 403/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.6675e-04
# Epoch 404/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.5921e-04
# Epoch 405/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 3.5184e-04
# Epoch 406/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.4461e-04
# Epoch 407/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 3.3753e-04
# Epoch 408/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 3.3060e-04
# Epoch 409/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 3.2380e-04
# Epoch 410/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 3.1715e-04
# Epoch 411/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 3.1064e-04
# Epoch 412/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 3.0426e-04
# Epoch 413/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.9801e-04
# Epoch 414/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.9189e-04
# Epoch 415/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.8589e-04
# Epoch 416/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.8002e-04
# Epoch 417/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.7427e-04
# Epoch 418/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.6863e-04
# Epoch 419/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.6312e-04
# Epoch 420/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.5771e-04
# Epoch 421/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.5242e-04
# Epoch 422/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.4723e-04
# Epoch 423/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.4215e-04
# Epoch 424/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.3718e-04
# Epoch 425/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 2.3231e-04
# Epoch 426/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.2754e-04
# Epoch 427/500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 19
#      16 ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)  # Corresponding outputs
#      18 # Train the model
# ---> 19 model.fit(xs, ys, epochs=500)  # Train for 500 epochs to minimize loss
#      21 # Use the model to predict a value
#      22 print(model.predict(np.array([7.0])))
#
# File ~/miniforge3/envs/ml/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/ml/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:366, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     364 callbacks.on_epoch_begin(epoch)
#     365 with epoch_iterator.catch_stop_iteration():
# --> 366     for step, iterator in epoch_iterator:
#     367         callbacks.on_train_batch_begin(step)
#     368         logs = self.train_function(iterator)
#
# File ~/miniforge3/envs/ml/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:729, in TFEpochIterator.__next__(self)
#     728 def __next__(self):
# --> 729     return next(self._epoch_iterator)
#
# File ~/miniforge3/envs/ml/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:102, in EpochIterator._enumerate_iterator(self)
#     100 if steps_per_epoch > 0:
#     101     if self._current_iterator is None or self.steps_per_epoch is None:
# --> 102         self._current_iterator = iter(self._get_iterator())
#     103         self._steps_seen = 0
#     104     for step in range(0, steps_per_epoch, self.steps_per_execution):
#
# File ~/miniforge3/envs/ml/lib/python3.12/site-packages/tensorflow/python/data/ops/dataset_ops.py:501, in DatasetV2.__iter__(self)
#     499 if context.executing_eagerly() or ops.inside_function():
#     500   with ops.colocate_with(self._variant_tensor):
# --> 501     return iterator_ops.OwnedIterator(self)
#     502 else:
#     503   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     504                      "iteration in eager mode or within tf.function.")
#
# File ~/miniforge3/envs/ml/lib/python3.12/site-packages/tensorflow/python/data/ops/iterator_ops.py:709, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     705   if (components is not None or element_spec is not None):
#     706     raise ValueError(
#     707         "When `dataset` is provided, `element_spec` and `components` must "
#     708         "not be specified.")
# --> 709   self._create_iterator(dataset)
#     711 self._get_next_call_count = 0
#
# File ~/miniforge3/envs/ml/lib/python3.12/site-packages/tensorflow/python/data/ops/iterator_ops.py:748, in OwnedIterator._create_iterator(self, dataset)
#     745   assert len(fulltype.args[0].args[0].args) == len(
#     746       self._flat_output_types)
#     747   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 748 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~/miniforge3/envs/ml/lib/python3.12/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3478, in make_iterator(dataset, iterator, name)
#    3476 if tld.is_eager:
#    3477   try:
# -> 3478     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3479       _ctx, "MakeIterator", name, dataset, iterator)
#    3480     return _result
#    3481   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# Episode 2: Computer vision by building a neural network with TensorFlow.
# What is computer vision? Computer vision is a branch of AI that allows computers to interpret and analyze visual data like images and videos, replicating human vision capabilities. It uses techniques like machine learning and deep learning to recognize objects, detect patterns, and understand pixels. Applications include face recognition, self-driving cars, medical imaging, and augmented reality.
# When you have an image, you have to give it an id so that a computer can know which image is which but when you are doing this, you have to give it a number id instead of a string id so that there is no english bias:
# ![](ImageID.png)
# Now, here is the exercise for the Mnist fashion data set: https://colab.research.google.com/github/lmoroney/dlaicourse/blob/master/Exercises/Exercise%202%20-%20Handwriting%20Recognition/Exercise2-Question.ipynbThis
# now below is the code for a computer vision model that uses the mnist data set to have the computer figure out where to place what items into 1 of the 10 categories of clothing:

# %%
import tensorflow as tf
# imports tensorflow
mnist = tf.keras.datasets.mnist
# loading in the mnist dataset

(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Loads in the training and testing images.


x_train, x_test = x_train / 255.0, x_test / 255.0
# normalize data value's between 1 and 0


model = tf.keras.models.Sequential([
    # This initializes a sequential model, which is a linear stack of layers. It allows you to define a simple feed-forward neural network by adding layers one after another.
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    #The Flatten layer reshapes the 2D input images (28x28 pixels) into a 1D array of 784 elements. This is necessary to pass the data to fully connected (dense) layers. The input_shape=(28, 28) specifies the shape of the input images.
    tf.keras.layers.Dense(128, activation='relu'),
    #This is a fully connected (dense) layer with 128 neurons. Each neuron is connected to all neurons in the previous layer. The activation function used is ReLU (Rectified Linear Unit), if a number is less than zero it turns to zero and otherwise the number keeps it size

    tf.keras.layers.Dense(10, activation='softmax')
    #This is another dense layer with 10 neurons, corresponding to the number of output classes (e.g., digits 0-9 if working with MNIST). The softmax activation function ensures that the outputs are probabilities that sum to 1, which is ideal for multi-class classification. sets the largest to 1 and the rest to 0.



])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# This compiles the model, specifying the optimizer and loss function.
# The optimizer='adam' uses the Adam optimization algorithm, which combines the benefits of RMSProp and momentum-based gradient descent.
# The loss='sparse_categorical_crossentropy' is used for multi-class classification tasks with integer-encoded labels.




model.fit(x_train, y_train, epochs=5)
#This trains the model on the train_images and train_labels dataset for 5 epochs (iterations over the full dataset). During training, the model adjusts its weights to minimize the loss function.
# Evaluate the model on test data
test_loss, test_acc = model.evaluate(x_test, y_test)
# This evaluates the trained model on the test dataset (test_images and test_labels), returning the loss (test_loss) and accuracy (test_acc). This helps to assess how well the model generalizes to unseen data.

print(f"Test accuracy: {test_acc}")
# prints test accuracy
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8726 - loss: 0.4439
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9640 - loss: 0.1234
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9759 - loss: 0.0815
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9821 - loss: 0.0589
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9872 - loss: 0.0442
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9728 - loss: 0.0878
# Test accuracy: 0.9779000282287598

# %% [markdown]
# Episode 3 & 4: Convolutions and Pooling:
# what is a convolution?
# A convolution is a filter that is used in machine learning and computer vision. With convolutions we are able to process a image down to its bare features that will match the labels. using many random values in filters we can find the best filter to match the image to the label to.
# what is pooling?: Pooling is a way to decrease the resolution of an image without actually damaging its integrity and makes it lighter for the program to handle and make it learn much faster.
# How does it work though?:
# Pooling: For every 2x2 pixels, it takes the one with the darkest value and it replaces the 4 pixels with a pixel of the darkest value.
# ![](PoolingExplained.png)
# ![](PoolingCode.png)
# Convolutions: We take 3x3 pixels from an image, then we define a 3x3 filter with specific values to multiply the images value, giving us a new image that has been filtered.
# ![](ConvolutionsExplained.png)
# ![](ConvolutionsCode.png)
# Now, there is one last lesson we are gonna learn, What looks Wrong in this code:
# ![](26x26Code.png)
# It shows that the convolutions are 26x26 rather than 28x28? You may think that his is wrong but it is actually not, as when you are doing convolutions with an image, you can only apply this filter away from the edge so it does not mess up because of the empty parts outside of the image.
# Here is the Exercise for pooling and convolutions: https://colab.research.google.com/github/lmoroney/dlaicourse/blob/master/Exercises/Exercise%203%20-%20Convolutions/Exercise%203%20-%20Question.ipynb
#
# Mnist Code improved using convolutions and pooling:

# %%
import tensorflow as tf

# Load the MNIST dataset
mnist = tf.keras.datasets.mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()

# Normalize the pixel values to the range 0-1
training_images = training_images / 255.0
test_images = test_images / 255.0

# Reshape the data to add a channel dimension (required for Conv2D)
training_images = training_images.reshape(-1, 28, 28, 1)
test_images = test_images.reshape(-1, 28, 28, 1)

# Define the model
model = tf.keras.models.Sequential([
    # First convolutional layer with pooling
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D(2, 2),

    # Second convolutional layer with pooling
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    # Flatten the output
    tf.keras.layers.Flatten(),

    # Fully connected dense layer
    tf.keras.layers.Dense(128, activation='relu'),

    # Output layer with 10 classes
    tf.keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(training_images, training_labels, epochs=5)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_accuracy}")
# Out:
# 2024-12-09 16:13:27.768530: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/anton/miniforge3/envs/ml/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.9048 - loss: 0.3019
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 40s 15ms/step - accuracy: 0.9871 - loss: 0.0427
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - accuracy: 0.9918 - loss: 0.0271
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - accuracy: 0.9934 - loss: 0.0191
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.9954 - loss: 0.0152
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9872 - loss: 0.0463
# Test accuracy: 0.9900000095367432

# %% [markdown]
# Wow! Using Convolutions and Pooling that was a lot more accurate! But it did take a quiet longer and put a much bigger strain on my computer compared to the other one without pooling or convolutions.

# %% [markdown]
# Episode 5&6: Real-world image classification using convolutional neural networks
# Ok before we build our model that deals with more complex images, we first gotta learn some new stuff:
# When we have multiple categories of images we want to store and use, how do we efficiently store all of these images into categories? simple, we create a generator:
# ![](Generator.png)
# using a generator you can have tensor flow automatically name a label based off of the directory.
# here is the Exercise for a CNN that tells the difference between a horse and a human: https://colab.research.google.com/github/lmoroney/dlaicourse/blob/master/Exercises/Exercise%204%20-%20Handling%20Complex%20Images/Exercise%204-Question.ipynb
# Now we will examine the code for a CNN that uses a generator to tell the difference between a human and a horse:

# %%
import tensorflow as tf  # TensorFlow is a library for deep learning and we’ll use it to build our model
import os  # Provides utilities to interact with the operating system
import zipfile  # Helps us work with ZIP files
from tensorflow.keras.preprocessing.image import ImageDataGenerator  # Prepares our images for training

DESIRED_ACCURACY = 0.999  # This is the accuracy we want the model to achieve before stopping training

# Download the dataset and save it locally
# !wget --no-check-certificate \
"https://storage.googleapis.com/learning-datasets/happy-or-sad.zip" \
-O "/tmp/happy-or-sad.zip"

# Unzip the downloaded file into a folder so we can access the images
zip_ref = zipfile.ZipFile("/tmp/happy-or-sad.zip", 'r')  # Open the zip file
zip_ref.extractall("/tmp/h-or-s")  # Extract the contents to this folder
zip_ref.close()  # Close the zip file

# Define a custom callback that stops training once the desired accuracy is reached
class myCallback(tf.keras.callbacks.Callback):  # We're subclassing the Callback class from TensorFlow
    def on_epoch_end(self, epoch, logs=None):  # This runs at the end of every epoch
        if logs.get('accuracy') >= DESIRED_ACCURACY:  # Check if the accuracy meets our threshold
            print("\nReached 99.9% accuracy so cancelling training!")  # Print a message to notify us
            self.model.stop_training = True  # Stop training if the condition is met

callbacks = myCallback()  # Create an instance of our custom callback

# Create an ImageDataGenerator to load and preprocess our images
train_datagen = ImageDataGenerator(rescale=1.0/255.0)  # Rescale image pixel values to range [0, 1] for normalization

# Load images from the directory and prepare them for training
train_generator = train_datagen.flow_from_directory(
    '/tmp/h-or-s',  # Path to the folder with training images
    target_size=(150, 150),  # Resize all images to 150x150 pixels
    batch_size=10,  # Load 10 images at a time for training
    class_mode='binary'  # We’re doing binary classification (happy or sad)
)

# Define the model architecture
model = tf.keras.models.Sequential([  # Sequential lets us stack layers in order
    tf.keras.layers.Conv2D(16, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    # A convolutional layer with 16 filters, a 3x3 kernel, ReLU activation, and input size of 150x150x3 (RGB)

    tf.keras.layers.MaxPooling2D(2, 2),
    # A pooling layer that reduces image size by taking the maximum value in a 2x2 window (down-sampling)

    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    # Another convolutional layer, but now with 32 filters for extracting more complex features

    tf.keras.layers.MaxPooling2D(2, 2),
    # Pooling again to further reduce the image size while keeping important features

    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    # A third convolutional layer with 64 filters for even deeper feature extraction

    tf.keras.layers.MaxPooling2D(2, 2),
    # And another pooling layer to continue down-sampling the feature maps

    tf.keras.layers.Flatten(),
    # Flatten the output from the convolutional layers to prepare it for the dense layers

    tf.keras.layers.Dense(512, activation='relu'),
    # A fully connected dense layer with 512 neurons and ReLU activation to learn non-linear patterns

    tf.keras.layers.Dense(1, activation='sigmoid')
    # The final output layer with a single neuron and sigmoid activation, because it's binary classification
])

# Compile the model with an optimizer, loss function, and evaluation metric
model.compile(
    loss='binary_crossentropy',  # Loss function for binary classification problems
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001),  # RMSprop optimizer with a learning rate of 0.001
    metrics=['accuracy']  # Track accuracy as the evaluation metric during training
)

# Train the model using the prepared data
history = model.fit(
    train_generator,  # The training data generator
    steps_per_epoch=8,  # Total number of steps (batches) per epoch (80 images / batch size of 10)
    epochs=20,  # Train for a maximum of 20 epochs
    callbacks=[callbacks]  # Use our custom callback to stop training when desired accuracy is reached
)
# Out:
# zsh:1: command not found: wget
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 12
#       9 get_ipython().system('wget --no-check-certificate  "https://storage.googleapis.com/learning-datasets/happy-or-sad.zip"  -"/tmp/happy-or-sad.zip"')
#      11 # Unzip the downloaded file into a folder so we can access the images
# ---> 12 zip_ref = zipfile.ZipFile("/tmp/happy-or-sad.zip", 'r')  # Open the zip file
#      13 zip_ref.extractall("/tmp/h-or-s")  # Extract the contents to this folder
#      14 zip_ref.close()  # Close the zip file
#
# File ~/miniforge3/envs/ml/lib/python3.12/zipfile/__init__.py:1331, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1329 while True:
#    1330     try:
# -> 1331         self.fp = io.open(file, filemode)
#    1332     except OSError:
#    1333         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/happy-or-sad.zip'

# %% [markdown]
# now we will get into a even harder challenge, a cat or dog CNN, here is the dataset:
# https://www.kaggle.com/c/dogs-vs-cats/data
# ,here is the exercise: https://colab.research.google.com/github/lmoroney/mlday-tokyo/blob/master/Lab6-Cats-v-Dogs.ipynb#scrollTo=7v55rWlQehzL
# and here is the answer:

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# Load the dataset
# !wget --no-check-certificate \
"https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip" \
-O "/tmp/cats_and_dogs_filtered.zip"

# Unzip the dataset
import zipfile
local_zip = '/tmp/cats_and_dogs_filtered.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# Define paths for training and validation directories
base_dir = '/tmp/cats_and_dogs_filtered'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# Training and validation subdirectories for cats and dogs
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

# Define a data generator for training and validation
train_datagen = ImageDataGenerator(rescale=1.0/255.0)  # Normalize pixel values to [0, 1]
validation_datagen = ImageDataGenerator(rescale=1.0/255.0)

# Flow training images in batches of 20 using train_datagen
train_generator = train_datagen.flow_from_directory(
    train_dir,               # Training directory path
    target_size=(150, 150),  # Resize all images to 150x150
    batch_size=20,           # Batch size
    class_mode='binary'      # Binary classification (cats and dogs)
)

# Flow validation images in batches of 20 using validation_datagen
validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(150, 150),
    batch_size=20,
    class_mode='binary'
)

# Define the CNN model
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')  # Single output node for binary classification
])

# Compile the model
model.compile(
    loss='binary_crossentropy',            # Binary crossentropy for binary classification
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001),  # Optimizer
    metrics=['accuracy']                   # Track accuracy during training
)

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=100,       # Number of batches per epoch
    epochs=15,                 # Number of epochs to train
    validation_data=validation_generator,
    validation_steps=50        # Number of batches for validation
)

# Evaluate the model
import matplotlib.pyplot as plt

# Plot training and validation accuracy over epochs
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend(loc=0)
plt.show()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend(loc=0)
plt.show()

# %% [markdown]
# Episodes 7: Image Augmentation and Overfitting.
# What is overfitting? Overfitting occurs when a model learns the training data too well, including its noise and specific patterns, resulting in poor generalization to new, unseen data. This happens when the model is too complex (e.g., too many parameters) for the amount of training data or lacks proper regularization.
# now what is image augmentation? Image augmentation is when we use a ImageDataGenerator to change an image into something else, this helps to stop overfitting and here is the exercise:
# https://colab.research.google.com/github/lmoroney/dlaicourse/blob/master/Course%202%20-%20Part%204%20-%20Lesson%202%20-%20Notebook%20(Cats%20v%20Dogs%20Augmentation).ipynb
# And here is the code for a CNN that uses a ImageDataGenerator:

# %%
# Import necessary libraries
import os  # For working with file paths
import zipfile  # To unzip the downloaded dataset
import tensorflow as tf  # TensorFlow for building and training the model
from tensorflow.keras.optimizers import RMSprop  # RMSprop optimizer for training
from tensorflow.keras.preprocessing.image import ImageDataGenerator  # For preprocessing and augmenting images

# Download the dataset of cats and dogs and save it to a temporary directory
# !wget --no-check-certificate \
https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
        -O /tmp/cats_and_dogs_filtered.zip

# Define the path to the downloaded zip file
local_zip = '/tmp/cats_and_dogs_filtered.zip'

# Extract the contents of the zip file
zip_ref = zipfile.ZipFile(local_zip, 'r')  # Open the zip file for reading
zip_ref.extractall('/tmp')  # Extract all files to the '/tmp' directory
zip_ref.close()  # Close the zip file after extracting

# Define the base directory for the dataset
base_dir = '/tmp/cats_and_dogs_filtered'

# Set paths to training and validation directories
train_dir = os.path.join(base_dir, 'train')  # Directory containing training data
validation_dir = os.path.join(base_dir, 'validation')  # Directory containing validation data

# Define paths for subdirectories of training and validation data
train_cats_dir = os.path.join(train_dir, 'cats')  # Training images of cats
train_dogs_dir = os.path.join(train_dir, 'dogs')  # Training images of dogs
validation_cats_dir = os.path.join(validation_dir, 'cats')  # Validation images of cats
validation_dogs_dir = os.path.join(validation_dir, 'dogs')  # Validation images of dogs

# Define the CNN model
model = tf.keras.models.Sequential([  # Sequential model allows stacking layers
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    # Convolutional layer with 32 filters, 3x3 kernel size, ReLU activation, and input size of 150x150x3 (RGB images)
    tf.keras.layers.MaxPooling2D(2, 2),  # Max pooling layer to reduce spatial dimensions

    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    # Second convolutional layer with 64 filters
    tf.keras.layers.MaxPooling2D(2, 2),  # Pooling to further downsample the image

    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    # Third convolutional layer with 128 filters
    tf.keras.layers.MaxPooling2D(2, 2),  # Pooling again

    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    # Fourth convolutional layer with 128 filters
    tf.keras.layers.MaxPooling2D(2, 2),  # Pooling again

    tf.keras.layers.Dropout(0.5),  # Dropout to reduce overfitting by randomly setting 50% of neurons to 0

    tf.keras.layers.Flatten(),  # Flatten layer to convert 3D feature maps to 1D vector

    tf.keras.layers.Dense(512, activation='relu'),
    # Dense layer with 512 neurons for learning high-level features

    tf.keras.layers.Dense(1, activation='sigmoid')
    # Output layer with 1 neuron and sigmoid activation for binary classification
])

# Compile the model
model.compile(
    loss='binary_crossentropy',  # Binary cross-entropy loss for binary classification
    optimizer=RMSprop(learning_rate=1e-4),  # RMSprop optimizer with a learning rate of 0.0001
    metrics=['accuracy']  # Track accuracy during training
)

# Define a data generator for training with data augmentation
train_datagen = ImageDataGenerator(
    rescale=1.0/255,  # Normalize pixel values to the range [0, 1]
    rotation_range=40,  # Randomly rotate images by up to 40 degrees
    width_shift_range=0.2,  # Randomly shift images horizontally by up to 20% of width
    height_shift_range=0.2,  # Randomly shift images vertically by up to 20% of height
    shear_range=0.2,  # Apply random shearing transformations
    zoom_range=0.2,  # Randomly zoom in/out by up to 20%
    horizontal_flip=True,  # Randomly flip images horizontally
    fill_mode='nearest'  # Fill any gaps created by transformations with the nearest pixel value
)

# Define a data generator for validation without augmentation
test_datagen = ImageDataGenerator(rescale=1.0/255)  # Only normalize pixel values

# Create a generator for training data
train_generator = train_datagen.flow_from_directory(
    train_dir,  # Source directory for training images
    target_size=(150, 150),  # Resize all images to 150x150 pixels
    batch_size=20,  # Load images in batches of 20
    class_mode='binary'  # Binary classification (cats or dogs)
)

# Create a generator for validation data
validation_generator = test_datagen.flow_from_directory(
    validation_dir,  # Source directory for validation images
    target_size=(150, 150),  # Resize all images to 150x150 pixels
    batch_size=20,  # Load images in batches of 20
    class_mode='binary'  # Binary classification
)

# Train the model
history = model.fit(
    train_generator,  # Training data generator
    steps_per_epoch=100,  # Number of training batches per epoch (2000 images / 20 images per batch)
    epochs=100,  # Train the model for 100 epochs
    validation_data=validation_generator,  # Validation data generator
    validation_steps=50,  # Number of validation batches per epoch (1000 images / 20 images per batch)
    verbose=2  # Print detailed logs during training
)

# %% [markdown]
# Episodes 8 & 9 & 10: Tokenizers and Using Sequencing API's in TensorFlow.
# When creating a program that recognizes words we Use word-based encoding and ASCII:
# Word-based encoding: for each new word in a sentence we give it a value so that the computer understands better the difference between 2 sentences.
# ASCII: a common coding format where letters and sounds are assigned a number from 0 to 255
# so we get something like this: output:{'i': 1, 'love': 2, 'my': 3, 'dog': 4, 'cat': 5}
# using this we can have it create a sentence like this: 1,2,3,5(i love my cat)
# Now here is an example in code format: https://colab.research.google.com/github/lmoroney/dlaicourse/blob/master/TensorFlow%20In%20Practice/Course%203%20-%20NLP/Course%203%20-%20Week%201%20-%20Lesson%201.ipynb#scrollTo=zaCMcjMQifQc or right here:

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# List of sentences to tokenize
sentences = [
    'i love my dog',
    'I, love my cat',
    'You love my dog!'
]

# Create a Tokenizer object with a vocabulary size limit of 100
tokenizer = Tokenizer(num_words=100)  # num_words limits the vocab to the top 100 most frequent words

# Fit the tokenizer on the sentences (build the word index)
tokenizer.fit_on_texts(sentences)

# Retrieve the word index generated by the tokenizer
word_index = tokenizer.word_index

# Print the word index
print(word_index)

# %% [markdown]
# Now we also gotta learn something else, what is padding?
# Padding is the process of adding extra values (usually zeros) to sequences to make them all the same length. Now here is a example of a Tokenizer that uses padding: https://colab.research.google.com/github/lmoroney/dlaicourse/blob/master/TensorFlow%20In%20Practice/Course%203%20-%20NLP/Course%203%20-%20Week%201%20-%20Lesson%202.ipynb#scrollTo=ArOPfBwyZtln or right here:

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# List of sentences to tokenize
sentences = [
    'I love my dog',
    'I love my cat',
    'You love my dog!',
    'Do you think my dog is amazing?'
]

# Create a tokenizer with a vocabulary size of 100 and an out-of-vocabulary (OOV) token
tokenizer = Tokenizer(num_words=100, oov_token="<OOV>")
tokenizer.fit_on_texts(sentences)  # Fit the tokenizer on the input sentences to build the word index

word_index = tokenizer.word_index  # Retrieve the word index (mapping of words to integers)
sequences = tokenizer.texts_to_sequences(sentences)  # Convert sentences into sequences of integers

# Pad the sequences to a maximum length of 5 (shorter sequences are left-padded with zeros)
padded = pad_sequences(sequences, maxlen=5)

# Display the word index, sequences, and padded sequences
print("\nWord Index = ", word_index)
print("\nSequences = ", sequences)
print("\nPadded Sequences:")
print(padded)

# Test data with new words that weren't in the original sentences
test_data = [
    'i really love my dog',
    'my dog loves my manatee'
]

# Convert the test data into sequences based on the original tokenizer
test_seq = tokenizer.texts_to_sequences(test_data)
print("\nTest Sequence = ", test_seq)

# Pad the test sequences to a maximum length of 10
padded_test_seq = pad_sequences(test_seq, maxlen=10)
print("\nPadded Test Sequence: ")
print(padded_test_seq)

# %% [markdown]
# Now we got one final task, and that is to create a sarcasm detector: https://colab.research.google.com/github/lmoroney/dlaicourse/blob/master/TensorFlow%20In%20Practice/Course%203%20-%20NLP/Course%203%20-%20Week%201%20-%20Lesson%202.ipynb and here is the answer down here:

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import json

# Load the dataset
with open('sarcasm.json', 'r') as f:
    data = json.load(f)

# Extract sentences (headlines) and labels (sarcasm or not)
sentences = [item['headline'] for item in data]
labels = [item['is_sarcastic'] for item in data]

# Tokenize the sentences
tokenizer = Tokenizer(num_words=10000, oov_token="<OOV>")
tokenizer.fit_on_texts(sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(sentences)

# Pad the sequences
padded = pad_sequences(sequences, padding='post', maxlen=100)

# Split data into training and testing sets
training_size = int(len(sentences) * 0.8)
train_sentences = padded[:training_size]
train_labels = labels[:training_size]
test_sentences = padded[training_size:]
test_labels = labels[training_size:]

# Build the model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(10000, 16, input_length=100),  # Embedding layer for text input
    tf.keras.layers.GlobalAveragePooling1D(),  # Reduces dimensions after embedding
    tf.keras.layers.Dense(24, activation='relu'),  # Fully connected hidden layer
    tf.keras.layers.Dense(1, activation='sigmoid')  # Output layer for binary classification
])

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(
    train_sentences, train_labels,
    epochs=10,
    validation_data=(test_sentences, test_labels),
    verbose=2
)

# Evaluate the model on test data
test_loss, test_accuracy = model.evaluate(test_sentences, test_labels, verbose=2)
print(f"Test Accuracy: {test_accuracy}")

# Test with new sentences
new_sentences = ["The weather is amazing today!", "Oh great, another Monday."]
new_sequences = tokenizer.texts_to_sequences(new_sentences)
new_padded = pad_sequences(new_sequences, padding='post', maxlen=100)
predictions = model.predict(new_padded)

# Display predictions
for i, sentence in enumerate(new_sentences):
    print(f"'{sentence}' -> Sarcasm score: {predictions[i][0]:.2f}")
